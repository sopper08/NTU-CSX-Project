# %%
import requests
from bs4 import BeautifulSoup

payload = {
    'from': '/bbs/Gossiping/index.html',
    'yes': 'yes'
}

req = requests.session()
res = req.post('https://www.ptt.cc/ask/over18', verify=False, data=payload)
res = req.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify=False)

soup = BeautifulSoup(res.text, "lxml")

for entry in soup.select('.r-ent'):
    print(entry)
# Out:
# /home/sopper/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /home/sopper/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /home/sopper/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# ...

# %%
# pttArticledict = {}
# tempdict = {}
pttpath = "https://www.ptt.cc"
for entry in soup.select('.r-ent'):
    print(entry.select('.title')[0].text[1:-1])
    print(entry.select('.author')[0].text)
    print(entry.select('.date')[0].text[1:])
    print(pttpath+entry.select('a')[0]['href'])
    print('-------------')
#     tempdict = {}
#     tempdict['title'] = entry.select('.title')[0].text
#     tempdict['author'] = entry.select('.author')[0].text
#     tempdict['date'] = entry.select('.date')[0].text
#     pttArticledict[entry.select('.title')[0].text] = tempdict
# pttArticledict
# Out:
# [問卦] 台灣需要肛交國嗎
# Marchosias
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161469.A.0E2.html
# -------------
# Re: [爆卦] 挺管人士在台大爺林大道刻字了
# bob120400
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161480.A.177.html
# -------------
# [新聞] 勞動節有感 蔡英文：落實六大勞工政策
# louiswoman
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161501.A.EA3.html
# -------------
# [問卦] 三、四天出國能去哪？
# ponponman123
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161502.A.405.html
# -------------
# [問卦] 政大的存在感怎這麼低
# ok8752665
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161527.A.807.html
# -------------
# [問卦] 六顆無限寶石贏的了死亡筆記本嗎
# twlight2013
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161527.A.68C.html
# -------------
# [新聞] 預測女嬰變男嬰…醫狠斬GG後落跑
# pal2007
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161536.A.024.html
# -------------
# Re: [爆卦] 吳茂昆準備解散台大校長遴選會
# violetking
# 5/01
# https://www.ptt.cc/bbs/Gossiping/M.1525161543.A.92E.html
# -------------
# [新聞] 韓正妹實況主企鵝妹在台爆紅 觀眾「斗內
# BerlinWu
# 5/01
# ...

# %%
# Content
res = req.get('https://www.ptt.cc/bbs/Gossiping/M.1525161543.A.92E.html', verify=False)
soup = BeautifulSoup(res.text, "lxml")
soup.select('meta')[7]['content'].replace('\n', ' ')
# Out:
# /home/sopper/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# '幫吳大部長想到理由了。 其實可以用跟否定管一樣的理由。 這些遴選委員都這樣挺管，已經有事實足認管有利害關係，有偏頗之虞了。 對於將來其他候選人欠缺公平。 大學自治的前提是要合法，而且校長選任無關教學研究，跟大學自治無關。 '

# %%
# IP
soup.select('.f2')[1].text.split(':')[2][1:-1]
# Out:
# '111.250.235.226'

# %%
# Time
soup.select('.f2')[3].text.split(',')[1][1:-1]
# Out:
# '05/01/2018 15:59:57'

# %%
# h_推文總數
for entry in soup.select('.push'):
    print(entry)
    print('--------')
# Out:
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kusowan</span><span class="f3 push-content">: 這招臺灣價值爆表，我覺得可以</span><span class="push-ipdatetime"> 05/01 16:00
# </span></div>
# --------
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">abbkg</span><span class="f3 push-content">: 看現在的名嘴就知道風向球是要解散台大遴選會</span><span class="push-ipdatetime"> 05/01 16:00
# </span></div>
# --------
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">windwater77</span><span class="f3 push-content">: 明天上教育部上班</span><span class="push-ipdatetime"> 05/01 16:01
# </span></div>
# --------
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">nixon</span><span class="f3 push-content">: 那就是任何得票的候選人都有這個問題，反而沒票的當選</span><span class="push-ipdatetime"> 05/01 16:01
# </span></div>
# --------
# ...

# %%
for entry in soup.select('.push'):
    print(entry.select('span')[0].text)
    print(entry.select('span')[1].text)
    print(entry.select('span')[2].text[2:])
    print(entry.select('span')[3].text[1:-1])
    print('--------')
# Out:
# →
# kusowan
# 這招臺灣價值爆表，我覺得可以
# 05/01 16:00
# --------
# 推
# abbkg
# 看現在的名嘴就知道風向球是要解散台大遴選會
# 05/01 16:00
# --------
# 推
# windwater77
# 明天上教育部上班
# 05/01 16:01
# --------
# →
# nixon
# 那就是任何得票的候選人都有這個問題，反而沒票的當選
# 05/01 16:01
# --------
# 推
# pxhome
# 尚方寶劍-行政法人法...
# 05/01 16:02
# --------
# →
# pxhome
# 教育部一定贏
# 05/01 16:02
# --------
# 推
# olaqe
# 高招!再組一次遴選委員會 這次名單要先呈送教育部
# 05/01 16:04
# --------
# 推
# b891050402
# 明天黨中央報到
# 05/01 16:05
# --------
# 推
# pxhome
# 程序法優先實體法，所以法律優位，拿大學自治來打訴訟有，
# 05/01 16:08
# --------
# →
# pxhome
# 如果教育部斧底抽薪，讓訴訟標的不存在，訴訟自然就沒意義
# 05/01 16:08
# --------
# →
# pxhome
# 了。要贏必須爭取過在董事會過半的董事支持，但是金權上
# 05/01 16:08
# --------
# →
# pxhome
# 教育部有絕對優勢。
# 05/01 16:09
# --------
# →
# teras
# ☎管爭議的法律研析 https://youtu.be/RuQfzAfx8cU?t=329☎
# 05/01 16:33
# --------
# →
# teras
# ☎選市長☎選市長☎選市長☎
# 05/01 16:33
# --------
# →
# teras
# ☎白痴KMT教育幫,把彭P踢出來當政論專業,現世報.哈哈哈☎
# 05/01 16:33
# --------
# →
# teras
# ☎KMT9.2真der蠻搞笑der。應該要珍惜它。哈哈哈☎
# 05/01 16:33
# --------
