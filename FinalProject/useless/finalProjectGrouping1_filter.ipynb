# %% [markdown]
# # finalProjectGrouping1_filter
# 將Ntu_Order的失敗訂單濾除，再做一次一樣的分析。

# %%
import pandas as pd
df_NtuOrderOri = pd.read_csv('data/Ntu_Orders.csv')

# %% [markdown]
# 留下訂單完成

# %%
df_NtuOrderOri_Fin = df_NtuOrderOri[df_NtuOrderOri['SalesOrderSlaveStatusDef']=='Finish']
df_NtuOrderOri_Fin['SalesOrderSlaveStatusDef'].head(10)
# Out:
# 0    Finish
# 1    Finish
# 2    Finish
# 3    Finish
# 4    Finish
# 5    Finish
# 6    Finish
# 7    Finish
# 8    Finish
# 9    Finish
# Name: SalesOrderSlaveStatusDef, dtype: object

# %% [markdown]
# 新增三個欄位：
# * promotionDiscUse: 計算使用promotion的數量，若PromotionDiscount小於零則設為1。
# * EcouponDisUse: 計算使用ecoupon的數量，若EcouponDiscount小於零則設為1。
# * orderSum: 計算訂單量，全部設為1。

# %%
df_NtuOrderOri_Fin['promotionDiscUse'] = 0
df_NtuOrderOri_Fin['promotionDiscUse'][df_NtuOrderOri_Fin['PromotionDiscount']<0] = 1
df_NtuOrderOri_Fin['EcouponDisUse'] = 0
df_NtuOrderOri_Fin['EcouponDisUse'][df_NtuOrderOri_Fin['EcouponDiscount']<0] = 1
df_NtuOrderOri_Fin['orderSum'] = 1
df_NtuOrderOri_Fin.head()
# Out:
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/sopper/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5984: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/sopper/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    SalesOrderSlaveId    DateId                              MemberId  \
# 0           26914456  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 1           26914457  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 2           26767644  20170101  C8B989DB-05F9-42D3-BD4F-E203482C5E58
# 3           26780512  20170101  C39E36F7-5091-48DA-BE8F-8CE043E009EE
# 4           26823950  20170102  7D87099A-B49C-4136-A8E9-F76BB5588B19
#
#    TradesOrderSlaveId  ShopId  SalePageId  \
# 0            26971960    1317        9804
# 1            26971961    1317        9804
# 2            26825136    1317       10118
# 3            26837997    1317       10036
# 4            26881442    1317       10268
#
#                                 TradesOrderGroupCode TrackSourceTypeDef  \
# 0  b'q\x14\xa49\xaa\\\xecs\xff6wH\xfbXd\x93\xfbf\...                Web
# 1  b'q\x14\xa49\xaa\\\xecs\xff6wH\xfbXd\x93\xfbf\...                Web
# 2  b'\x1d\x8f}\x12lu>.&\xfc\xbc\xe0\xd2\xad\xe5\x...                Web
# 3  b'&QI#u)\xf8\xf7\n6\x01~\xd1\xf3,\x1f\xb8\xe3\...                Web
# 4  b'\xfd\x0b\x9ee\xdc\xaea@\x102;jX\xfek\x99m\x1...                Web
#
#   TrackChannelTypeDef TrackDeviceTypeDef    ...     \
# 0               Brand             Mobile    ...
# 1               Brand             Mobile    ...
# 2               Brand             Mobile    ...
# 3               Brand             Mobile    ...
# 4               Brand             Mobile    ...
#
#   SalesOrderSlaveTotalPayment  SalesOrderSlaveDateTime  \
# 0                       374.0  2017-01-03 23:11:47.207
# 1                       374.0  2017-01-03 23:11:47.223
# 2                       316.0  2017-01-01 17:21:32.113
# 3                       483.0  2017-01-01 21:41:58.153
# 4                       401.0  2017-01-02 15:37:33.610
#
#   SalesOrderSlaveStatusDef PayProfileTypeDef  ShippingProfileTypeDef  \
# 0                   Finish       SevenEleven             SevenEleven
# 1                   Finish       SevenEleven             SevenEleven
# 2                   Finish            Family                  Family
# 3                   Finish            Family                  Family
# 4                   Finish            Family                  Family
#
#    EcouponId  IsSalePageGift  promotionDiscUse  EcouponDisUse  orderSum
# 0        NaN           False                 1              0         1
# 1        NaN           False                 1              0         1
# 2        NaN           False                 1              0         1
# 3        NaN           False                 1              0         1
# 4        NaN           False                 1              0         1
#
# [5 rows x 30 columns]

# %% [markdown]
# 接著以memberid做groupby sum

# %%
data = df_NtuOrderOri_Fin.groupby('MemberId')['promotionDiscUse', 'EcouponDisUse', 'orderSum', 'PromotionDiscount', 'EcouponDiscount', 'SalesOrderSlaveTotalPayment'].sum()
df_NOOri_Fin_byMemId = pd.DataFrame(data)
df_NOOri_Fin_byMemId.head()
# Out:
#                                       promotionDiscUse  EcouponDisUse  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E                18              0
# 000037B9-82D7-4F41-A748-FD64AF00A535                 5              0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018                 0              0
# 00008557-6564-46EB-8B00-70D3DEE91FF0                 0              2
# 000248F1-4864-40B7-A987-E27884C0971C                 0              0
#
#                                       orderSum  PromotionDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E        19             -516.0
# 000037B9-82D7-4F41-A748-FD64AF00A535         5             -100.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018         1                0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0         2                0.0
# 000248F1-4864-40B7-A987-E27884C0971C         3                0.0
#
#                                       EcouponDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E              0.0
# 000037B9-82D7-4F41-A748-FD64AF00A535              0.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018              0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0           -150.0
# 000248F1-4864-40B7-A987-E27884C0971C              0.0
#
#                                       SalesOrderSlaveTotalPayment
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E                       5542.0
# 000037B9-82D7-4F41-A748-FD64AF00A535                       1196.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018                        316.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0                        699.0
# 000248F1-4864-40B7-A987-E27884C0971C                        597.0

# %% [markdown]
# 將折扣取abs

# %%
df_NOOri_Fin_byMemId = df_NOOri_Fin_byMemId.abs()
df_NOOri_Fin_byMemId.head()
# Out:
#                                       promotionDiscUse  EcouponDisUse  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E              18.0            0.0
# 000037B9-82D7-4F41-A748-FD64AF00A535               5.0            0.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018               0.0            0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0               0.0            2.0
# 000248F1-4864-40B7-A987-E27884C0971C               0.0            0.0
#
#                                       orderSum  PromotionDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E      19.0              516.0
# 000037B9-82D7-4F41-A748-FD64AF00A535       5.0              100.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018       1.0                0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0       2.0                0.0
# 000248F1-4864-40B7-A987-E27884C0971C       3.0                0.0
#
#                                       EcouponDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E              0.0
# 000037B9-82D7-4F41-A748-FD64AF00A535              0.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018              0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0            150.0
# 000248F1-4864-40B7-A987-E27884C0971C              0.0
#
#                                       SalesOrderSlaveTotalPayment
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E                       5542.0
# 000037B9-82D7-4F41-A748-FD64AF00A535                       1196.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018                        316.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0                        699.0
# 000248F1-4864-40B7-A987-E27884C0971C                        597.0

# %% [markdown]
# 新增兩個欄位：
# * actOrderPercent(%) = (PromotionDisUse+EcouponDisUse/orderSum)*100
# * payDCPercent(%) = (PromotionDiscount+EcouponDiscount)/(PromotionDiscount+EcouponDiscount+SalesOrderSlaveTotalPayment)*100

# %%
df_NOOri_Fin_byMemId['payDCPercent(%)'] = 100 * (df_NOOri_Fin_byMemId['PromotionDiscount']+df_NOOri_Fin_byMemId['EcouponDiscount'])/(df_NOOri_Fin_byMemId['SalesOrderSlaveTotalPayment']+df_NOOri_Fin_byMemId['PromotionDiscount']+df_NOOri_Fin_byMemId['EcouponDiscount'])
df_NOOri_Fin_byMemId['actOrderPercent(%)'] = 100 * (df_NOOri_Fin_byMemId['promotionDiscUse']+df_NOOri_Fin_byMemId['EcouponDisUse'])/df_NOOri_Fin_byMemId['orderSum']
df_NOOri_Fin_byMemId.head()
# Out:
#                                       promotionDiscUse  EcouponDisUse  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E              18.0            0.0
# 000037B9-82D7-4F41-A748-FD64AF00A535               5.0            0.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018               0.0            0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0               0.0            2.0
# 000248F1-4864-40B7-A987-E27884C0971C               0.0            0.0
#
#                                       orderSum  PromotionDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E      19.0              516.0
# 000037B9-82D7-4F41-A748-FD64AF00A535       5.0              100.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018       1.0                0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0       2.0                0.0
# 000248F1-4864-40B7-A987-E27884C0971C       3.0                0.0
#
#                                       EcouponDiscount  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E              0.0
# 000037B9-82D7-4F41-A748-FD64AF00A535              0.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018              0.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0            150.0
# 000248F1-4864-40B7-A987-E27884C0971C              0.0
#
#                                       SalesOrderSlaveTotalPayment  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E                       5542.0
# 000037B9-82D7-4F41-A748-FD64AF00A535                       1196.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018                        316.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0                        699.0
# 000248F1-4864-40B7-A987-E27884C0971C                        597.0
#
#                                       payDCPercent(%)  actOrderPercent(%)
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E         8.517663           94.736842
# 000037B9-82D7-4F41-A748-FD64AF00A535         7.716049          100.000000
# 00004BE7-17B5-4DA8-A31D-673BCD22F018         0.000000            0.000000
# 00008557-6564-46EB-8B00-70D3DEE91FF0        17.667845          100.000000
# 000248F1-4864-40B7-A987-E27884C0971C         0.000000            0.000000

# %% [markdown]
# 接著抽出payDCPercent(%)、actOrderPercent(%)、orderSum，繪製散點圖

# %%
df_percent = pd.DataFrame({
    'orderSum': df_NOOri_Fin_byMemId['orderSum'],
    'actOrderPercent(%)': df_NOOri_Fin_byMemId['actOrderPercent(%)'],
    'payDCPercent(%)': df_NOOri_Fin_byMemId['payDCPercent(%)']
})
df_percent.head()
# Out:
#                                       actOrderPercent(%)  orderSum  \
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E           94.736842      19.0
# 000037B9-82D7-4F41-A748-FD64AF00A535          100.000000       5.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018            0.000000       1.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0          100.000000       2.0
# 000248F1-4864-40B7-A987-E27884C0971C            0.000000       3.0
#
#                                       payDCPercent(%)
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E         8.517663
# 000037B9-82D7-4F41-A748-FD64AF00A535         7.716049
# 00004BE7-17B5-4DA8-A31D-673BCD22F018         0.000000
# 00008557-6564-46EB-8B00-70D3DEE91FF0        17.667845
# 000248F1-4864-40B7-A987-E27884C0971C         0.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 

matplotlib.rcParams.update({'font.size': 100})
plt.figure(figsize=(100,50))
plt.xlabel("actOrderPercent(%)")
plt.ylabel("payDCPercent(%)")
# colors = RGB(df_percent['orderSUm'],0,0)
cm = plt.cm.get_cmap('Reds')
area = np.pi * 30
sc = plt.scatter(df_percent['actOrderPercent(%)'], df_percent['payDCPercent(%)'], s=area, c=df_percent['orderSum']/2, vmin=0, vmax=35, cmap=cm, alpha=1)
plt.colorbar(sc)
plt.show()

# %% [markdown]
# 發現須先將客戶訂單量做出分級，t再來做分級繪圖

# %%
df_order = pd.DataFrame({
    'orderSum': df_NOOri_Fin_byMemId['orderSum']
})
df_order.head()
# Out:
#                                       orderSum
# MemberId
# 00002962-4E01-4D5B-A23C-AF05A965212E      19.0
# 000037B9-82D7-4F41-A748-FD64AF00A535       5.0
# 00004BE7-17B5-4DA8-A31D-673BCD22F018       1.0
# 00008557-6564-46EB-8B00-70D3DEE91FF0       2.0
# 000248F1-4864-40B7-A987-E27884C0971C       3.0

# %% [markdown]
# 以10訂單量為單位，製作出每增加10筆訂單的級距

# %% [markdown]
# 如果要讓10呈現成010:
# "{0:0>3}".format(10)
# 其中
# {0 : 0 > 3}
#  │   │ │ │
#  │   │ │ └─ Width of 3
#  │   │ └─ Align Right
#  │   └─ Fill with '0'
#  └─ Element index

# %%
sum_Mem = len(df_order)
check = 0
index = 0
step = 1
dict_order10 = {}
while check < sum_Mem:
    temp = len(df_order[(df_order['orderSum']>index)&(df_order['orderSum']<=(index+step))])
    dict_order10['{0:0>3}~{1:0>3}'.format(index, index+step)] = temp
    index = index + step
    check = check + temp
df_order10 = pd.Series(dict_order10)
df_order10
# Out:
# 000~001    16137
# 001~002    26693
# 002~003    35579
# 003~004    29996
# 004~005    23681
# 005~006    18489
# 006~007    14357
# 007~008    11267
# 008~009     9140
# 009~010     7623
# 010~011     6267
# 011~012     5080
# 012~013     4307
# 013~014     3553
# 014~015     3135
# 015~016     2650
# 016~017     2314
# 017~018     1975
# 018~019     1685
# 019~020     1512
# 020~021     1328
# 021~022     1174
# 022~023      999
# 023~024      888
# 024~025      772
# 025~026      696
# 026~027      649
# 027~028      577
# 028~029      545
# 029~030      455
#            ...
# 443~444        0
# 444~445        0
# 445~446        0
# 446~447        0
# 447~448        0
# 448~449        0
# 449~450        0
# 450~451        0
# 451~452        0
# 452~453        0
# 453~454        0
# 454~455        0
# 455~456        0
# 456~457        0
# 457~458        0
# 458~459        0
# 459~460        0
# 460~461        0
# 461~462        0
# 462~463        0
# 463~464        0
# 464~465        0
# 465~466        0
# 466~467        0
# 467~468        0
# 468~469        0
# 469~470        0
# 470~471        0
# 471~472        0
# 472~473        1
# Length: 473, dtype: int64

# %% [markdown]
# 發現到45筆訂單時，人數下降到100以下，接下來決定級距！

# %%
df_NtuOrderOri_Fin[df_NtuOrderOri_Fin['MemberId']=='725C0679-97AC-47AD-8FC5-B1C4099285BA']
# Out:
#          SalesOrderSlaveId    DateId                              MemberId  \
# 9374              34390885  20170503  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 9584              34164802  20170430  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 13395             34390883  20170503  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 13396             34390884  20170503  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 19932             49568297  20171213  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 32573             33792190  20170424  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 39086             27323148  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 39087             27323150  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 43893             49985861  20171219  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 43894             49985862  20171219  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 55159             33792199  20170424  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 68138             31453012  20170320  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 68315             33792192  20170424  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 86471             49985863  20171219  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 102155            27323142  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 102156            27323143  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 102157            27323147  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 102158            27323149  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 102282            27323152  20170110  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 103989            31453015  20170320  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 108433            49025753  20171206  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 131514            33792191  20170424  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 135701            49026333  20171206  725C0679-97AC-47AD-8FC5-B1C4099285BA
# 136090            49026331  20171206  725C0679-97AC-47AD-8FC5-B1C4099285BA
#
b'ic\xe4\xeb\x9c\x113\xe0\xa4k\x88vo\x86R\xc1*...                Web
# 2249419  b'ic\xe4\xeb\x9c\x113\xe0\xa4k\x88vo\x86R\xc1*...                Web
# 2249422  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249424  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249426  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249429  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249430  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249505  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249506  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249507  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249508  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249509  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249511  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249513  b'\xb2\xf3i\x03\x04\x8bz\xd3c\x8d,\x19x\xca\t\...                Web
# 2249521  b'\x04\xfe\x96\x82\xa0\xc8\xdd\x80|\xf4\x81E\x...                Web
# 2249522  b'\x04\xfe\x96\x82\xa0\xc8\xdd\x80|\xf4\x81E\x...                Web
# 2252247  b'\xba\xc4\xa8\xea[9\xd3\x82\x17\xf2\x16\x96)X...                Web
# 2252248  b'\xba\xc4\xa8\xea[9\xd3\x82\x17\xf2\x16\x96)X...                Web
# 2252249  b'\xba\xc4\xa8\xea[9\xd3\x82\x17\xf2\x16\x96)X...                Web
# 2252250  b'\xba\xc4\xa8\xea[9\xd3\x82\x17\xf2\x16\x96)X...                Web
# 2263068  b'\xc3\xa5S\xe9<\xf4\xc3\xe8\x99\x82;>\xab\xcf...                Web
# 2263069  b'\xc3\xa5S\xe9<\xf4\xc3\xe8\x99\x82;>\xab\xcf...                Web
#
#         TrackChannelTypeDef TrackDeviceTypeDef    ...     \
# 9374                  Brand                 PC    ...
# 9584                  Brand                 PC    ...
# 13395                 Brand                 PC    ...
# 13396                 Brand                 PC    ...
# 19932                 Brand                 PC    ...
# 32573                 Brand                 PC    ...
# 39086                 Brand                 PC    ...
# 39087                 Brand                 PC    ...
# 43893                 Brand                 PC    ...
# 43894                 Brand                 PC    ...
# 55159                 Brand                 PC    ...
# 68138                 Brand                 PC    ...
# 68315                 Brand                 PC    ...
# 86471                 Brand                 PC    ...
# 102155                Brand                 PC    ...
# 102156                Brand                 PC    ...
# 102157                Brand                 PC    ...
# 102158                Brand                 PC    ...
# 102282                Brand                 PC    ...
# 103989                Brand                 PC    ...
# 108433                Brand                 PC    ...
# 131514                Brand                 PC    ...
# 135701                Brand                 PC    ...
# 136090                Brand                 PC    ...
# 153952                Brand                 PC    ...
# 153953                Brand                 PC    ...
# 153955                Brand                 PC    ...
# 153956                Brand                 PC    ...
# 154818                Brand                 PC    ...
# 156099                Brand                 PC    ...
# ...                     ...                ...    ...
# 2249408               Brand                 PC    ...
# 2249410               Brand                 PC    ...
# 2249411               Brand                 PC    ...
# 2249412               Brand                 PC    ...
# 2249413               Brand                 PC    ...
# 2249414               Brand                 PC    ...
# 2249415               Brand                 PC    ...
# 2249417               Brand                 PC    ...
# 2249418               Brand                 PC    ...
# 2249419               Brand                 PC    ...
# 2249422               Brand                 PC    ...
# 2249424               Brand                 PC    ...
# 2249426               Brand                 PC    ...
# 2249429               Brand                 PC    ...
# 2249430               Brand                 PC    ...
# 2249505               Brand                 PC    ...
# 2249506               Brand                 PC    ...
# 2249507               Brand                 PC    ...
# 2249508               Brand                 PC    ...
# 2249509               Brand                 PC    ...
# 2249511               Brand                 PC    ...
# 2249513               Brand                 PC    ...
# 2249521               Brand                 PC    ...
# 2249522               Brand                 PC    ...
# 2252247               Brand                 PC    ...
# 2252248               Brand                 PC    ...
# 2252249                       199.0  2017-02-07 15:57:31.467
# 2252250                       199.0  2017-02-07 15:57:31.483
# 2263068                       595.0  2017-12-19 15:33:24.137
# 2263069                       595.0  2017-12-19 15:33:24.157
#
#         SalesOrderSlaveStatusDef PayProfileTypeDef  ShippingProfileTypeDef  \
# 9374                      Finish            Family                  Family
# 9584                      Finish            Family                  Family
# 13395                     Finish            Family                  Family
# 13396                     Finish            Family                  Family
# 19932                     Finish            Family                  Family
# 32573                     Finish            Family                  Family
# 39086                     Finish            Family                  Family
# 39087                     Finish            Family                  Family
# 43893                     Finish            Family                  Family
# 43894                     Finish            Family                  Family
# 55159                     Finish            Family                  Family
# 68138                     Finish            Family                  Family
# 68315                     Finish            Family                  Family
# 86471                     Finish            Family                  Family
# 102155                    Finish            Family                  Family
# 102156                    Finish            Family                  Family
# 102157                    Finish            Family                  Family
# 102158                    Finish            Family                  Family
# 102282                    Finish            Family                  Family
# 103989                    Finish            Family                  Family
# 108433                    Finish            Family                  Family
# 131514                    Finish            Family                  Family
# 135701                    Finish            Family                  Family
# 136090                    Finish            Family                  Family
# 153952                    Finish            Family                  Family
# 153953                    Finish            Family                  Family
# 153955                    Finish            Family                  Family
# 153956                    Finish            Family                  Family
# 154818                    Finish            Family                  Family
# 156099                    Finish            Family                  Family
# ...                          ...               ...                     ...
# 2249408                   Finish            Family                  Family
# 2249410                   Finish            Family                  Family
# 2249411                   Finish            Family                  Family
# 2249412                   Finish            Family                  Family
# 2249413                   Finish            Family                  Family
# 2249414                   Finish            Family                  Family
# 2249415                   Finish            Family                  Family
# 2249417                   Finish            Family                  Family
# 2249418                   Finish            Family                  Family
# 2249419                   Finish            Family                  Family
# 2249422                   Finish            Family                  Family
# 2249424                   Finish            Family                  Family
# 2249426                   Finish            Family                  Family
# 2249429                   Finish            Family                  Family
# 2249430                   Finish            Family                  Family
# 2249505                   Finish            Family                  Family
# 2249506                   Finish            Family                  Family
# 2249507                   Finish            Family                  Family
# 2249508                   Finish            Family                  Family
# 2249509                   Finish            Family                  Family
# 2249511                   Finish            Family                  Family
# 2249513                   Finish            Family                  Family
# 2249521                   Finish            Family                  Family
# 2249522                   Finish            Family                  Family
# 2252247                   Finish            Family                  Family
# 2252248                   Finish            Family                  Family
# 2252249                   Finish            Family                  Family
# 2252250                   Finish            Family                  Family
# 2263068                   Finish            Family                  Family
# 2263069                   Finish            Family                  Family
#
#          EcouponId  IsSalePageGift  promotionDiscUse  EcouponDisUse  orderSum
# 9374           NaN           False                 1              0         1
# 9584           NaN           False                 0              0         1
# 13395          NaN           False                 1              0         1
# 13396          NaN           False                 1              0         1
# 19932        242.0           False                 1              1         1
# 32573          NaN           False                 0              0         1
# 39086          NaN           False                 1              0         1
# 39087          NaN           False                 1              0         1
# 43893          NaN           False                 1              0         1
# 43894          NaN           False                 1              0         1
# 55159          NaN           False                 0              0         1
# 68138          NaN           False                 0              0         1
# 68315          NaN           False                 0              0         1
# 86471          NaN           False                 1              0         1
# 102155         NaN           False                 1              0         1
# 102156         NaN           False                 1              0         1
# 102157         NaN           False                 1              0         1
# 102158         NaN           False                 1              0         1
# 102282         NaN           False                 1              0         1
# 103989         NaN           False                 0              0         1
# 108433       235.0           False                 0              0         1
# 131514         NaN           False                 0              0         1
# 135701       226.0           False                 0              0         1
# 136090       226.0           False                 1              1         1
# 153952         NaN           False                 0              0         1
# 153953         NaN           False                 0              0         1
# 153955         NaN           False                 0              0         1
# 153956         NaN           False                 0              0         1
# 154818         NaN           False                 0              0         1
# 156099         NaN           False                 0              0         1
# ...            ...             ...               ...            ...       ...
# 2249408        NaN           False                 1              0         1
# 2249410        NaN           False                 1              0         1
# 2249411        NaN           False                 1              0         1
# 2249412        NaN           False                 1              0         1
# 2249413        NaN           False                 1              0         1
# 2249414        NaN           False                 1              0         1
# 2249415        NaN           False                 1              0         1
# 2249417        NaN           False                 1              0         1
# 2249418        NaN           False                 1              0         1
# 2249419        NaN           False                 1              0         1
# 2249422        NaN           False                 1              0         1
# 2249424        NaN           False                 1              0         1
# 2249426        NaN           False                 1              0         1
# 2249429        NaN           False                 1              0         1
# 2249430        NaN           False                 1              0         1
# 2249505        NaN           False                 1              0         1
# 2249506        NaN           False                 1              0         1
# 2249507        NaN           False                 1              0         1
# 2249508        NaN           False                 1              0         1
# 2249509        NaN           False                 1              0         1
# 2249511        NaN           False                 1              0         1
# 2249513        NaN           False                 1              0         1
# 2249521        NaN           False                 1              0         1
# 2249522        NaN           False                 1              0         1
# 2252247        NaN           False                 0              0         1
# 2252248        NaN           False                 0              0         1
# 2252249        NaN           False                 0              0         1
# 2252250        NaN           False                 0              0         1
# 2263068        NaN           False                 1              0         1
# 2263069        NaN           False                 1              0         1
#
# [473 rows x 30 columns]

# %% [markdown]
# 真的是400多筆，厲害厲害！

# %% [markdown]
# 以下是分級繪圖

# %%
matplotlib.rcParams.update({'font.size': 100})
index = 0
step = 2
for i in range(1,5):
    df_percent_step = df_percent[(df_percent['orderSum']>i)&(df_percent['orderSum']<(i+2))]
    plt.figure(i)
    plt.figure(figsize=(100,50))
    plt.xlabel("actOrderPercent(%)")
    plt.ylabel("payDCPercent(%)")
    cm = plt.cm.get_cmap('Reds')
    area = np.pi * 100
    sc = plt.scatter(
        df_percent_step['actOrderPercent(%)'], 
        df_percent_step['payDCPercent(%)'], 
        s=area, 
        c=df_percent_step['orderSum']*0.01, 
        vmin=index, 
        vmax=(index+step), 
        cmap=cm, 
        alpha=1)
    plt.colorbar(sc)
    index = index + step
plt.show()

# %% [markdown]
# 分級繪圖後發現效果不顯著，將橫軸改為orderSum，actOrderPercent(%)改為深淺。

# %%
plt.figure(figsize=(100,50))
plt.xlabel("orderSum")
plt.ylabel("payDCPercent(%)")
cm = plt.cm.get_cmap('Reds')
area = np.pi * 100
sc = plt.scatter(
    df_percent['orderSum'], 
    df_percent['payDCPercent(%)'], 
    s=area, 
    c=df_percent['actOrderPercent(%)']*0.01,
    cmap=cm, 
    alpha=1)
plt.colorbar(sc)
plt.show()

# %% [markdown]
# 更改x軸後，分群狀況似乎更明顯了！看來又要重作一份，不過滿值得的！
