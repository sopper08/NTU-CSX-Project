# %% [markdown]
# # finalProjectGrouping4
# 將finalProjectGroupining3以時間分割

# %%
import pandas as pd
df_Order_ori = pd.read_csv('data/Ntu_Orders.csv')

# %%
df = df_Order_ori.copy()
data = df.groupby(by=['LevelOneCategoryName', 'LevelTwoCategoryName', 'LevelThreeCategoryName', 'LevelFourCategoryName'])['IsGift'].sum()
df1 = pd.DataFrame(data)
df1
# Out:
#                                                                                         IsGift
# LevelOneCategoryName LevelTwoCategoryName LevelThreeCategoryName LevelFourCategoryName
# 戶外、運動、汽機車用品          比基尼、泳裝、配件            比基尼、泳裝                 二件、三件、多件式               False
# 手機、相機、拍立得、耳機         智慧型手機配件              其它品牌區                  保護套/殼                   False
# 服裝、內睡衣               內衣                   內褲                     三角褲                     False
#                                                                  平口褲                     False
#                                           款式搜尋                   心機厚墊爆乳內衣                False
#                                                                  日系蕾絲內衣                  False
#                                                                  水鑽美背內衣                  False
#                                                                  無鋼圈運動BRA                False
# ...

# %% [markdown]
# 根據分類來分類夏裝(1)/冬裝(-1)/無關夏冬(0)：
# * 夏裝 -> 1
#     * 二件、三件、多件式
#     * 內搭比基尼
#     * 洋裝
#     * 背心/小可愛
#     * 休閒短裙/褲
#     * 休閒長裙/褲
#     * 單寧短裙/褲
# * 冬裝 -> -1
#     * 針織衫
#     * 雪紡/棉麻衫
#     * 高領衫/毛衣
#     * 內搭褲
#     * 圍巾
#     * 皮衣/風衣/大衣
#     * 罩衫/針織/造型外套
#     * 連帽/棉外套
# * 無關冬夏 -> 0
#     * 成套衣褲組
#     * 保護套/殼
#     * 三角褲
#     * 平口褲
#     * 心機厚墊爆乳內衣
#     * 日系蕾絲內衣
#     * 水鑽美背內衣
#     * 無鋼圈運動BRA
#     * 舒適無痕內衣
#     * 集中包覆內衣
#     * 隱形胸罩
#     * T恤/帽T
#     * 襯衫
#     * 單寧長裙/褲
#     * 連身裙/褲
#     * 女性襪類
#     * 披肩
#     * 西裝外套
#     * 其他
#     * 其他
#     * 其他
#     * 其他
#     * 其他
#     * 髮圈/髮箍
#     * 髮夾

# %%
df_cls = df_Order_ori.copy()
df_cls['ordertype'] = 0
df_cls['ordertype'][
    (df_cls['LevelFourCategoryName']=='二件、三件、多件式')|
    (df_cls['LevelFourCategoryName']=='內搭比基尼')|
    (df_cls['LevelFourCategoryName']=='洋裝')|
    (df_cls['LevelFourCategoryName']=='背心/小可愛')|
    (df_cls['LevelFourCategoryName']=='休閒短裙/褲')|
    (df_cls['LevelFourCategoryName']=='休閒長裙/褲')|
    (df_cls['LevelFourCategoryName']=='單寧短裙/褲')]=1
df_cls['ordertype'][
    (df_cls['LevelFourCategoryName']=='針織衫')|
    (df_cls['LevelFourCategoryName']=='雪紡/棉麻衫')|
    (df_cls['LevelFourCategoryName']=='高領衫/毛衣')|
    (df_cls['LevelFourCategoryName']=='內搭褲')|
    (df_cls['LevelFourCategoryName']=='圍巾')|
    (df_cls['LevelFourCategoryName']=='皮衣/風衣/大衣')|
    (df_cls['LevelFourCategoryName']=='罩衫/針織/造型外套')|
    (df_cls['LevelFourCategoryName']=='連帽/棉外套')]=-1
# Out:
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/sopper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_cls[df_cls['SalesOrderSlaveStatusDef']=='Finish']
df_cls.head()
# Out:
#    SalesOrderSlaveId    DateId                              MemberId  \
# 0           26914456  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 1           26914457  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 2           26767644  20170101  C8B989DB-05F9-42D3-BD4F-E203482C5E58
# 3           26780512  20170101  C39E36F7-5091-48DA-BE8F-8CE043E009EE
# 4           26823950  20170102  7D87099A-B49C-4136-A8E9-F76BB5588B19
#
#    TradesOrderSlaveId  ShopId  SalePageId  \
# 0            26971960    1317        9804
# 1            26971961    1317        9804
# 2            26825136    1317       10118
# 3            26837997    1317       10036
# 4            26881442    1317       10268
#
#                                 TradesOrderGroupCode TrackSourceTypeDef  \
# 0  b'q\x14\xa49\xaa\\\xecs\xff6wH\xfbXd\x93\xfbf\...                Web
# 1  b'q\x14\xa49\xaa\\\xecs\xff6wH\xfbXd\x93\xfbf\...                Web
# 2  b'\x1d\x8f}\x12lu>.&\xfc\xbc\xe0\xd2\xad\xe5\x...                Web
# ...

# %%
data = df_cls.groupby(by=['MemberId', 'TradesOrderGroupCode'], as_index=False)['PromotionDiscount', 'EcouponDiscount', 'SalesOrderSlaveTotalPayment', 'ordertype'].sum()
df_cls_byMID = pd.DataFrame(data)
df_cls_byMID
# Out:
#                                     MemberId  \
# 0       00002962-4E01-4D5B-A23C-AF05A965212E
# 1       00002962-4E01-4D5B-A23C-AF05A965212E
# 2       000037B9-82D7-4F41-A748-FD64AF00A535
# 3       00004BE7-17B5-4DA8-A31D-673BCD22F018
# 4       00008557-6564-46EB-8B00-70D3DEE91FF0
# 5       00008557-6564-46EB-8B00-70D3DEE91FF0
# 6       000248F1-4864-40B7-A987-E27884C0971C
# 7       000250B7-3E12-4E2F-8DFC-69ACFFCA40E9
# 8       00025802-0D68-43EA-B1ED-FB3C9CD849EB
# 9       0002954A-1267-4D54-8029-75F33C465F9B
# 10      0002954A-1267-4D54-8029-75F33C465F9B
# 11      0002971E-4BEF-4F61-8B60-79E137794422
# 12      0002B1F3-8C4B-457F-85A9-7CD5AB62DEA3
# 13      0002B1F3-8C4B-457F-85A9-7CD5AB62DEA3
# 14      0002BC73-DD5D-4A3F-92BA-781027F0AD84
# 15      0002C910-4401-42AA-9B56-06D02595518C
# 16      0002C910-4401-42AA-9B56-06D02595518C
# 17      0002C910-4401-42AA-9B56-06D02595518C
# 18      00030386-0E49-4F5D-AE62-9D3DE3B8A882
# 19      00030386-0E49-4F5D-AE62-9D3DE3B8A882
# ...
